# %%
#import data
import pandas as pd
df=pd.read_excel('health_data(30k)entries (1).xlsx')
df.head()
# Out:
#    age  sex  trestbps  chol  thalach  oldpeak  thal  heart rate  temperature  \
# 0   51    1       167   271      163        0     2         128          111
# 1   60    1       122   362      150        1     3         115          100
# 2   88    1       141   347      160        2     1          76          105
# 3   41    1       121   335      166        1     1          72          115
# 4   53    0       140   190      166        1     3          94           97
#
#    blood pressure  o2  abdnormal  Unnamed: 12  Unnamed: 13  Unnamed: 14  \
# 0              88  93          0          NaN          NaN          NaN
# 1             106  91          1          NaN          NaN          NaN
# 2             109  98          1          NaN          NaN          NaN
# 3              85  90          1          NaN          NaN          NaN
# 4             109  98          1          NaN          NaN          NaN
#
#    Unnamed: 15  Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             30000 non-null  int64
#  1   sex             30000 non-null  int64
#  2   trestbps        30000 non-null  int64
#  3   chol            30000 non-null  int64
#  4   thalach         30000 non-null  int64
#  5   oldpeak         30000 non-null  int64
#  6   thal            30000 non-null  int64
#  7   heart rate      30000 non-null  int64
#  8   temperature     30000 non-null  int64
#  9   blood pressure  30000 non-null  int64
#  10  o2              30000 non-null  int64
#  11  abdnormal       30000 non-null  int64
#  12  Unnamed: 12     0 non-null      float64
#  13  Unnamed: 13     0 non-null      float64
#  14  Unnamed: 14     0 non-null      float64
#  15  Unnamed: 15     0 non-null      float64
#  16  Unnamed: 16     0 non-null      float64
# ...

# %%
# Summary statistics
df.describe()
# Out:
#                 age           sex      trestbps          chol       thalach  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      59.889700      0.499300    142.606333    265.719067    161.951467
# std       17.647947      0.500008     19.038301     66.779671      7.215302
# min       30.000000      0.000000    110.000000    150.000000    150.000000
# 25%       45.000000      0.000000    126.000000    208.000000    156.000000
# 50%       60.000000      0.000000    143.000000    266.000000    162.000000
# 75%       75.000000      1.000000    159.000000    324.000000    168.000000
# max       90.000000      1.000000    175.000000    380.000000    174.000000
#
#             oldpeak          thal    heart rate   temperature  blood pressure  \
# count  30000.000000  30000.000000  30000.000000  30000.000000     30000.00000
# mean       1.001100      1.999067     99.622667    102.490233       100.05730
# ...

# %%
# Visualizing missing values
import pandas as pd
import matplotlib.pyplot as plt  # Import matplotlib.pyplot
import seaborn as sns
plt.figure(figsize=(12,6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap')
plt.show()

# %%
# Correlation matrix
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
# Boxplot for 'temperature'
plt.figure(figsize=(8,4))
sns.boxplot(x='abdnormal', y='temperature', data=df)
plt.title('Temperature by Abdnormal')
plt.show()

# Boxplot for 'chol'
plt.figure(figsize=(8,4))
sns.boxplot(x='abdnormal', y='chol', data=df)
plt.title('Cholesterol by Abdnormal')
plt.show()

# Boxplot for 'blood pressure'
plt.figure(figsize=(8,4))
sns.boxplot(x='abdnormal', y='blood pressure', data=df)
plt.title('Blood Pressure by Abdnormal')
plt.show()

# %%
#data analyze
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#data analyze
sns.stripplot(x='abdnormal', y='temperature' ,data =df)
# Out:
# <Axes: xlabel='abdnormal', ylabel='temperature'>

# %%
#data_analyze
import plotly.express as px
import plotly

# %%
#data cleanining(exploring the data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             30000 non-null  int64
#  1   sex             30000 non-null  int64
#  2   trestbps        30000 non-null  int64
#  3   chol            30000 non-null  int64
#  4   thalach         30000 non-null  int64
#  5   oldpeak         30000 non-null  int64
#  6   thal            30000 non-null  int64
#  7   heart rate      30000 non-null  int64
#  8   temperature     30000 non-null  int64
#  9   blood pressure  30000 non-null  int64
#  10  o2              30000 non-null  int64
#  11  abdnormal       30000 non-null  int64
#  12  Unnamed: 12     0 non-null      float64
#  13  Unnamed: 13     0 non-null      float64
#  14  Unnamed: 14     0 non-null      float64
#  15  Unnamed: 15     0 non-null      float64
#  16  Unnamed: 16     0 non-null      float64
# ...

# %%
#data cleaning
df.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
df.isnull().any()
# Out:
# age               False
# sex               False
# trestbps          False
# chol              False
# thalach           False
# oldpeak           False
# thal              False
# heart rate        False
# temperature       False
# blood pressure    False
# o2                False
# abdnormal         False
# Unnamed: 12        True
# Unnamed: 13        True
# Unnamed: 14        True
# Unnamed: 15        True
# Unnamed: 16        True
# Unnamed: 17        True
# Unnamed: 18        True
# Unnamed: 19        True
# dtype: bool

# %%
df.dropna(axis=1)
# Out:
#        age  sex  trestbps  chol  thalach  oldpeak  thal  heart rate  \
# 0       51    1       167   271      163        0     2         128
# 1       60    1       122   362      150        1     3         115
# 2       88    1       141   347      160        2     1          76
# 3       41    1       121   335      166        1     1          72
# 4       53    0       140   190      166        1     3          94
# ...    ...  ...       ...   ...      ...      ...   ...         ...
# 29995   89    1       162   199      163        1     1          81
# 29996   85    1       174   225      150        2     1          78
# 29997   68    0       132   169      159        1     1         124
# 29998   80    1       172   251      153        0     3         113
# 29999   83    1       113   253      160        2     1          87
#
#        temperature  blood pressure  o2  abdnormal
# 0              111              88  93          0
# ...

# %%
df.dropna(axis=0)
# Out:
# Empty DataFrame
# Columns: [age, sex, trestbps, chol, thalach, oldpeak, thal, heart rate, temperature, blood pressure, o2, abdnormal, Unnamed: 12, Unnamed: 13, Unnamed: 14, Unnamed: 15, Unnamed: 16, Unnamed: 17, Unnamed: 18, Unnamed: 19]
# Index: []

# %%
#Finding the nan column
df.isnull().any()
# Out:
# age               False
# sex               False
# trestbps          False
# chol              False
# thalach           False
# oldpeak           False
# thal              False
# heart rate        False
# temperature       False
# blood pressure    False
# o2                False
# abdnormal         False
# Unnamed: 12        True
# Unnamed: 13        True
# Unnamed: 14        True
# Unnamed: 15        True
# Unnamed: 16        True
# Unnamed: 17        True
# Unnamed: 18        True
# Unnamed: 19        True
# dtype: bool

# %%
# Dropping irrelevant columns
columns_to_drop = ['Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
                  'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19']
df.drop(columns=columns_to_drop, axis=1, inplace=True)

# %%
# Dropping rows with any missing values
df.dropna(inplace=True)

# %%
# Verify no missing values remain
print(df.isnull().sum())

# Display updated DataFrame information
df.info()
# Out:
# age               0
# sex               0
# trestbps          0
# chol              0
# thalach           0
# oldpeak           0
# thal              0
# heart rate        0
# temperature       0
# blood pressure    0
# o2                0
# abdnormal         0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             30000 non-null  int64
#  1   sex             30000 non-null  int64
#  2   trestbps        30000 non-null  int64
#  3   chol            30000 non-null  int64
#  4   thalach         30000 non-null  int64
#  5   oldpeak         30000 non-null  int64
#  6   thal            30000 non-null  int64
#  7   heart rate      30000 non-null  int64
#  8   temperature     30000 non-null  int64
#  9   blood pressure  30000 non-null  int64
#  10  o2              30000 non-null  int64
# ...

# %%
# Define feature variables and the target
X = df.iloc[:, 0:11]  # Assuming the first column is an ID or irrelevant
Y = df.iloc[:, -1]     # Assuming the last column is the target 'abdnormal'

# Apply SelectKBest with chi2 to select top 5 features
selector = SelectKBest(score_func=chi2, k=5)
selector.fit(X, Y)

# Get the scores for each feature
scores = selector.scores_
feature_scores = pd.DataFrame({'Feature': X.columns, 'Score': scores})
feature_scores = feature_scores.sort_values(by='Score', ascending=False)

print("Feature Scores:\n", feature_scores)
# Out:
# Feature Scores:
#             Feature        Score
# 8      temperature  5233.000667
# 7       heart rate     5.519094
# 0              age     2.366495
# 1              sex     1.915751
# 2         trestbps     1.143466
# 9   blood pressure     0.961404
# 6             thal     0.810945
# 5          oldpeak     0.773735
# 4          thalach     0.091372
# 10              o2     0.042676
# 3             chol     0.001478

# %%
selected_features = feature_scores['Feature'].head(5).tolist()
print("Selected Features:", selected_features)

X_selected = df[selected_features]
y = df['abdnormal']
# Out:
# Selected Features: ['temperature', 'heart rate', 'age', 'sex', 'trestbps']

# %%
# Split the data into train and test sets
# !pip install scikit-learn  # Install scikit-learn if you haven't already
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_selected, y,
                                                    test_size=0.4,
                                                    random_state=100)
print("Training Set Shape:", X_train.shape)
print("Testing Set Shape:", X_test.shape)
# Out:
# ...
# Training Set Shape: (18000, 5)
# Testing Set Shape: (12000, 5)

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Predict on test data
from sklearn.metrics import accuracy_score, classification_report
y_pred = rf_model.predict(X_test)

# Calculate accuracy
score_rf = round(accuracy_score(y_pred, y_test) * 100, 2)
print("Accuracy of the Random Forest model: {}%".format(score_rf))

# Detailed classification report
print("Classification Report:\n", classification_report(y_test, y_pred, zero_division=1))
# Out:
# Accuracy of the Random Forest model: 72.0%
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.72      0.73      0.73      6111
#            1       0.72      0.71      0.71      5889
#
#     accuracy                           0.72     12000
#    macro avg       0.72      0.72      0.72     12000
# weighted avg       0.72      0.72      0.72     12000

# %%
# !pip install shap

# %%
#Using shap model
import shap

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
# Create SHAP explainer
explainer = shap.TreeExplainer(rf_model)

# Calculate SHAP values for the training data
shap_values = explainer.shap_values(X_test)

# %%
# SHAP summary plot
shap.summary_plot(shap_values[:,:,1], X_test)

# %%
shap.initjs()
shap.force_plot(explainer.expected_value[1], shap_values[:,:,0][0], X_test.iloc[0])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
# Getting the index of 'age'
temperature_index = X_test.columns.get_loc('temperature')
shap.dependence_plot(temperature_index, shap_values[:, :, 1], X_test)

# %%
print(X_test.columns)
# Out:
# Index(['temperature', 'heart rate', 'age', 'sex', 'trestbps'], dtype='object')

# %%
# Decision plot
shap.decision_plot(explainer.expected_value[1], shap_values[0][1])

# %%
# Example input data (replace with your actual input data)
input_data = {
    'temperature': [47],       # Example temperature value
    'chol': [100],               # Example cholesterol value
    'blood pressure': [69],
    'heart rate':[50]# Example blood pressure value
}

# Convert input data to DataFrame
input_df = pd.DataFrame(input_data)
print("Input Data:\n", input_df)

# Ensure the input has the same features as the training data
input_encoded = input_df.reindex(columns=X_selected.columns, fill_value=0)
print("Encoded Input Data:\n", input_encoded)

# Make prediction using the trained model
prediction = rf_model.predict(input_encoded)
print("Prediction (0 = Not Diseased, 1 = Diseased):", prediction[0])
# Out:
# Input Data:
#     temperature  chol  blood pressure  heart rate
# 0           47   100              69          50
# Encoded Input Data:
#     temperature  heart rate  age  sex  trestbps
# 0           47          50    0    0         0
# Prediction (0 = Not Diseased, 1 = Diseased): 1
